# %%
from pyspark.sql import SparkSession
from pyspark.ml.regression import LinearRegression
from pyspark.ml.linalg import Vectors #importing vectors from linearalgebra library
from pyspark.ml.feature import VectorAssembler #vector assembler form features lib
from pyspark.sql.functions import col, when


spark = SparkSession.builder.appName('lr_example').getOrCreate()

# %%
data = sqlContext.sql ("SELECT * FROM Ecommerce_Customers_csv")

# %%
data.printSchema()
#data.na.drop()
for item in data.head(1)[0]:
  print (item)
#data.show()

# %%
#data.columns
assembler = VectorAssembler(inputCols = ['Email', 'Address', 'Avatar', 'Avg Session Length', 'Time on App', 'Time on Website', 'Length of Membership', 'Yearly Amount Spent'], outputCol = 'features')

# %%
output = assembler.transform(data)
#output.select('features').show()
